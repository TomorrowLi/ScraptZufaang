# %%
import pandas as pd
data=pd.read_csv(r'H:\Python\zufang_scrapy\zufang.csv')
data.head()
# Out:
#   area house_area house_type orientation  price rent_style  \
# 0   萧山        65㎡       2室2厅          朝南   3500         整租
# 1   滨江       130㎡       3室2厅          朝南   5000         整租
# 2   上城       150㎡       3室2厅         朝南北  10000         整租
# 3   上城       156㎡       3室2厅         朝南北  12000         整租
# 4   上城        68㎡       1室1厅          朝南   5500         整租
#
#                           title  url
# 0  钱江世纪城口水天城利二花苑利一家园嘉润公馆旁丽晶国际2房  NaN
# 1  诚租,寰宇天下钱江新城,一个好到没话说的好房子,大小都有  NaN
# 2  娃哈哈勇进全明户型中高层,配套齐全,有固定车位,4号线!  NaN
# 3      春江花月 精装三房 豪装带地暖 家具 求素质住户  NaN
# 4  工作的白领,小夫妻入住正好合适!会所楼上,房间,客厅朝南  NaN

# %%
data.head(10)
# Out:
#   area house_area house_type orientation   price rent_style  \
# 0   萧山        65㎡       2室2厅          朝南    3500         整租
# 1   滨江       130㎡       3室2厅          朝南    5000         整租
# 2   上城       150㎡       3室2厅         朝南北   10000         整租
# 3   上城       156㎡       3室2厅         朝南北   12000         整租
# 4   上城        68㎡       1室1厅          朝南    5500         整租
# 5   江干       180㎡       3室2厅         朝南北   14000         整租
# 6   余杭        84㎡       2室1厅          朝南    2200         整租
# 7   拱墅        30㎡       1户合租          朝北    2100       合租次卧
# 8   西湖      4505㎡       9室5厅         朝南北  100000         整租
# 9   江干        15㎡       3室1厅          朝南    1000         整租
#
#                             title  url
# 0    钱江世纪城口水天城利二花苑利一家园嘉润公馆旁丽晶国际2房  NaN
# 1    诚租,寰宇天下钱江新城,一个好到没话说的好房子,大小都有  NaN
# 2    娃哈哈勇进全明户型中高层,配套齐全,有固定车位,4号线!  NaN
# 3        春江花月 精装三房 豪装带地暖 家具 求素质住户  NaN
# 4    工作的白领,小夫妻入住正好合适!会所楼上,房间,客厅朝南  NaN
# 5  城市之星开发商样板房 精品东边套 大三房 两个车位 全新出租  NaN
# ...

# %%
data.tail()
# Out:
#      area house_area house_type orientation  price rent_style  \
# 4232   海淀       179㎡       4室2厅         朝西南  17000         整租
# 4233   东城       210㎡       2室2厅         朝东北  30000         整租
# 4234   海淀       263㎡       5室2厅         朝南北  38000         整租
# 4235   东城       152㎡       2室2厅         朝西南  25000         整租
# 4236   海淀        98㎡       2室1厅         朝南北   5800         整租
#
#                                  title  url
# 4232   远大园四区+明厨双明卫+家电齐全+干净整洁+配套完善+看房方便  NaN
# 4233  东直门 当代 东北2居 210平 30000元 万国城 北京公馆  NaN
# 4234      上河村平层五居室,宽敞明亮,采光充足,有车位,看房方便。  NaN
# 4235  东直门 当代 西南2居 152平 25000 随时看房 随时起租  NaN
# 4236         玉海园 2居室 楼层带电梯 出租,精装修 看房随时  NaN

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
data['orientation'].value_counts().plot(kind='barh',rot=0)

# %%
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
data['orientation'].value_counts().plot(kind='barh',rot=0)
plt.show()

# %%
data['rent_style'].value_counts().plot(kind='barh',rot=0)
plt.show()

# %%
data['house_type'].value_counts().plot(kind='barh',rot=0)
plt.show()

# %%
import jieba
from wordcloud import WordCloud
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['address'][n]))
    for seg in seg_list:
        if seg not in seg_list:
            final=final+seg+' '
my_wordcloud=WordCloud(font_path=r'C:\Windows\Fonts\simkaf.ttf',width=1000,height=600).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-fff18b528a33> in <module>()
#       4 stopword=['NaN']
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['house_type'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(font_path=r'C:\Windows\Fonts\simkaf.ttf',width=1000,height=600).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\李明\AppData\Local\Temp\jieba.cache
# Loading model cost 1.023 seconds.
# Prefix dict has been built succesfully.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-35d6b64fdda6> in <module>()
#       6         if seg not in seg_list:
#       7             final=final+seg+' '
# ----> 8 my_wordcloud=WordCloud(font_path=r'C:\Windows\Fonts\simkaf.ttf',width=1000,height=600).generate(final)
#       9 plt.imshow(my_wordcloud)
#      10 plt.axis('off')
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     569         self
#     570         """
# --> 571         return self.generate_from_text(text)
#     572
#     573     def _check_generated(self):
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['house_type'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(font_path=r'C:\Windows\Fonts\simkaf.ttf',width=1000,height=600).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-604722495077> in <module>()
#       6         if seg not in stopword:
#       7             final=final+seg+' '
# ----> 8 my_wordcloud=WordCloud(font_path=r'C:\Windows\Fonts\simkaf.ttf',width=1000,height=600).generate(final)
#       9 plt.imshow(my_wordcloud)
#      10 plt.axis('off')
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     569         self
#     570         """
# --> 571         return self.generate_from_text(text)
#     572
#     573     def _check_generated(self):
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     551         """
#     552         words = self.process_text(text)
# --> 553         self.generate_from_frequencies(words)
#     554         return self
#     555
#
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['house_type'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1000,height=600).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['area'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=2000,height=600,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['area'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=2000,height=600,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['area'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=14000,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-178402e181e4> in <module>()
#       6         if seg not in stopword:
#       7             final=final+seg+' '
# ----> 8 my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=14000,margin=2).generate(final)
#       9 plt.imshow(my_wordcloud)
#      10 plt.axis('off')
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     569         self
#     570         """
# --> 571         return self.generate_from_text(text)
#     572
#     573     def _check_generated(self):
#
# e:\python\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     551         """
#     552         words = self.process_text(text)
# --> 553         self.generate_from_frequencies(words)
#     554         return self
#     555
#
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['area'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=1400,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
my_wordcloud.to_file('show_Chinese.png')  # 把词云保存下来
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-de26610f6e03> in <module>()
# ----> 1 wc.to_file('show_Chinese.png')  # 把词云保存下来
#
# NameError: name 'wc' is not defined

# %%
my_wordcloud.to_file('show_Chinese.png')  # 把词云保存下来

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['price'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=1400,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price\t'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-61df29a2d4f6> in <module>()
#       2 stopword=['NaN']
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['price'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=1400,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5d0e0eac8d1f> in <module>()
#       2 stopword=['NaN']
#       3 for n in range(data.shape[0]):
# ----> 4     seg_list=list(jieba.cut(data['price'][n]))
#       5     for seg in seg_list:
#       6         if seg not in stopword:
#
# e:\python\lib\site-packages\jieba\__init__.py in cut(self, sentence, cut_all, HMM)
#     280             - HMM: Whether to use the Hidden Markov Model.
#     281         '''
# --> 282         sentence = strdecode(sentence)
#     283
#     284         if cut_all:
#
# e:\python\lib\site-packages\jieba\_compat.py in strdecode(sentence)
#      35     if not isinstance(sentence, text_type):
#      36         try:
# ---> 37             sentence = sentence.decode('utf-8')
#      38         except UnicodeDecodeError:
#      39             sentence = sentence.decode('gbk', 'ignore')
#
# ...

# %%
final=''
stopword=['NaN']
for n in range(data.shape[0]):
    seg_list=list(jieba.cut(data['area'][n]))
    for seg in seg_list:
        if seg not in stopword:
            final=final+seg+' '
my_wordcloud=WordCloud(collocations=False,font_path=r'C:\Windows\Fonts\simfang.ttf',width=1400,height=1400,margin=2).generate(final)
plt.imshow(my_wordcloud)
plt.axis('off')
plt.show()

# %%
import numpy as np
data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode=np.linspace(0,1.5,25))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-383f3297d70d> in <module>()
#       1 import numpy as np
# ----> 2 data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode=np.linspace(0,1.5,25))
#       3 plt.show()
#
# e:\python\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
import numpy as np
data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode = np.linspace(0,1.5,25))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d90bb94fd438> in <module>()
#       1 import numpy as np
# ----> 2 data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode = np.linspace(0,1.5,25))
#       3 plt.show()
#
# e:\python\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
import numpy as np
data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode = np.linspace(0,1.5,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6d8da260b66f> in <module>()
#       1 import numpy as np
# ----> 2 data['area'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode = np.linspace(0,1.5,20))
#       3 plt.show()
#
# e:\python\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
data2=list(map(lambda x:(data['house_type'][x],data['price'][x],ramge(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#   File "<ipython-input-25-50adb05ab364>", line 2
#     data3=pd.DataFrame(data2)
#         ^
# SyntaxError: invalid syntax

# %%
data2=list(map(lambda x:(data['house_type'][x],data['price'][x],range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#   File "<ipython-input-26-a5d218554c63>", line 2
#     data3=pd.DataFrame(data2)
#         ^
# SyntaxError: invalid syntax

# %%
data2=list(map(lambda x:(data['house_type'][x],data['price'][x],range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#   File "<ipython-input-27-b2d5427dc684>", line 2
#     data3=pd.DataFrame(data2)
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data=pd.read_csv(r'H:\Python\zufang_scrapy\zufang.csv')
data.head()
# Out:
#   area house_area house_type orientation  price rent_style  \
# 0   萧山        65㎡       2室2厅          朝南   3500         整租
# 1   滨江       130㎡       3室2厅          朝南   5000         整租
# 2   上城       150㎡       3室2厅         朝南北  10000         整租
# 3   上城       156㎡       3室2厅         朝南北  12000         整租
# 4   上城        68㎡       1室1厅          朝南   5500         整租
#
#                           title  url
# 0  钱江世纪城口水天城利二花苑利一家园嘉润公馆旁丽晶国际2房  NaN
# 1  诚租,寰宇天下钱江新城,一个好到没话说的好房子,大小都有  NaN
# 2  娃哈哈勇进全明户型中高层,配套齐全,有固定车位,4号线!  NaN
# 3      春江花月 精装三房 豪装带地暖 家具 求素质住户  NaN
# 4  工作的白领,小夫妻入住正好合适!会所楼上,房间,客厅朝南  NaN

# %%
data2=list(map(lambda x:(data['house_type'][x],data['price'][x]),range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#   File "<ipython-input-2-b2d5427dc684>", line 2
#     data3=pd.DataFrame(data2)
#         ^
# SyntaxError: invalid syntax

# %%
data2=list(map(lambda x:(data['house_type'][x],data['price'][x],range(len(data)))))
data3=pd.DataFrame(data2)
data3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-83d950b23c92> in <module>()
# ----> 1 data2=list(map(lambda x:(data['house_type'][x],data['price'][x],range(len(data)))))
#       2 data3=pd.DataFrame(data2)
#       3 data3
#
# TypeError: map() must have at least two arguments.

# %%
data2=list(map(lambda x:(data['area'][x],data['house_type'][x],data['price'][x]),range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#          0       1
# 0     2室2厅    3500
# 1     3室2厅    5000
# 2     3室2厅   10000
# 3     3室2厅   12000
# 4     1室1厅    5500
# 5     3室2厅   14000
# 6     2室1厅    2200
# 7     1户合租    2100
# 8     9室5厅  100000
# 9     3室1厅    1000
# 10    3室2厅    5200
# 11    3室2厅    4200
# 12    1室1厅    2000
# 13    2室2厅    1400
# 14    3室2厅    8500
# 15    3室2厅    4000
# 16    3室2厅    3800
# 17    3室2厅    3500
# 18    2室1厅    3000
# 19    2室2厅    3100
# 20    9室5厅  100000
# 21    3室2厅    6600
# 22    2室2厅    7000
# 23    2室2厅    5500
# 24    3室2厅    5500
# 25    2室2厅    3600
# 26    1室1厅    2800
# 27    3室2厅    4200
# 28    3室2厅    5000
# 29    2室1厅    4500
# ...    ...     ...
# 4207  9室1厅  149999
# 4208  1室1厅    4200
# 4209  3室1厅    1700
# 4210  1室1厅   36000
# 4211  1室1厅    1000
# 4212  4室2厅   43000
# 4213  2室2厅   16500
# 4214  2室1厅    3600
# 4215  2室1厅    1650
# 4216  1室1厅    4200
# 4217  2室1厅    3450
# 4218  3室2厅   20000
# 4219  3户合租    1600
# 4220  3户合租     850
# 4221  3室2厅   15000
# ...

# %%
data2=list(map(lambda x:(data['area'][x],data['house_type'][x],data['price'][x]),range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#         0     1       2
# 0      萧山  2室2厅    3500
# 1      滨江  3室2厅    5000
# 2      上城  3室2厅   10000
# 3      上城  3室2厅   12000
# 4      上城  1室1厅    5500
# 5      江干  3室2厅   14000
# 6      余杭  2室1厅    2200
# 7      拱墅  1户合租    2100
# 8      西湖  9室5厅  100000
# 9      江干  3室1厅    1000
# 10     西湖  3室2厅    5200
# 11     余杭  3室2厅    4200
# 12     滨江  1室1厅    2000
# 13     临安  2室2厅    1400
# 14     江干  3室2厅    8500
# 15     西湖  3室2厅    4000
# 16     西湖  3室2厅    3800
# 17     萧山  3室2厅    3500
# 18     萧山  2室1厅    3000
# 19     萧山  2室2厅    3100
# 20     西湖  9室5厅  100000
# 21     上城  3室2厅    6600
# 22     江干  2室2厅    7000
# 23     上城  2室2厅    5500
# 24     滨江  3室2厅    5500
# 25     滨江  2室2厅    3600
# 26     滨江  1室1厅    2800
# 27     滨江  3室2厅    4200
# 28     余杭  3室2厅    5000
# 29     拱墅  2室1厅    4500
# ...   ...   ...     ...
# 4207   东城  9室1厅  149999
# 4208   海淀  1室1厅    4200
# 4209   房山  3室1厅    1700
# 4210   朝阳  1室1厅   36000
# 4211   丰台  1室1厅    1000
# 4212   朝阳  4室2厅   43000
# ...

# %%
data2=list(map(lambda x:(data['area'][x],data['price'][x]),range(len(data))))
data3=pd.DataFrame(data2)
data3
# Out:
#         0       1
# 0      萧山    3500
# 1      滨江    5000
# 2      上城   10000
# 3      上城   12000
# 4      上城    5500
# 5      江干   14000
# 6      余杭    2200
# 7      拱墅    2100
# 8      西湖  100000
# 9      江干    1000
# 10     西湖    5200
# 11     余杭    4200
# 12     滨江    2000
# 13     临安    1400
# 14     江干    8500
# 15     西湖    4000
# 16     西湖    3800
# 17     萧山    3500
# 18     萧山    3000
# 19     萧山    3100
# 20     西湖  100000
# 21     上城    6600
# 22     江干    7000
# 23     上城    5500
# 24     滨江    5500
# 25     滨江    3600
# 26     滨江    2800
# 27     滨江    4200
# 28     余杭    5000
# 29     拱墅    4500
# ...   ...     ...
# 4207   东城  149999
# 4208   海淀    4200
# 4209   房山    1700
# 4210   朝阳   36000
# 4211   丰台    1000
# 4212   朝阳   43000
# 4213   西城   16500
# 4214   昌平    3600
# 4215   燕郊    1650
# 4216   丰台    4200
# 4217  门头沟    3450
# 4218   朝阳   20000
# 4219   丰台    1600
# 4220   朝阳     850
# 4221   东城   15000
# 4222   密云    2500
# 4223   朝阳   10500
# 4224   海淀   20000
# ...

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr vlaue=geo.cast(data4)
geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-1-a97cea4ed670>", line 1
#     import pyecharts Gao
#                        ^
# SyntaxError: invalid syntax

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr,vlaue=geo.cast(data4)
geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-2-7738e799b235>", line 4
#     attr vlaue=geo.cast(data4)
#              ^
# SyntaxError: invalid syntax

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('zufang','Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr,vlaue=geo.cast(data4)
geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-3-81cf3e43a960>", line 5
#     geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
#                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('zufang','Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr,vlaue=geo.cast(data4)
geo.add(attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-4-2c7d0e4ded2e>", line 5
#     geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
#                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('zufang','Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr,vlaue=geo.cast(data4)
geo.add(attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-5-c911bd2b8c34>", line 5
#     geo.add(attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
#                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
from pyecharts import Gao
data4=list(map(lambda x:(data3.groupby(0).mean()[1].index[x],data3.groupby(0).mean()[1].values[x]),range(len(data3.groupby(0)))))
geo=Gao('zufang','Tomorrow',title_color='#fff',title_pos='left',width=1200,height=600,background_color='#404a59')
attr,vlaue=geo.cast(data4)
geo.add('',attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
geo
# Out:
#   File "<ipython-input-6-c911bd2b8c34>", line 5
#     geo.add(attr,value,type='heatmap',is_visualmap=True,visual_range[0,300],visual_text_color('#fff'))
#                                                        ^
# SyntaxError: positional argument follows keyword argument
